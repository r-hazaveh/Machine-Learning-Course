# %%
import numpy as np
help(np)

# %%
a = np.array([1,23,5,8])

# %%
a[1]
# Out:
# 23

# %%
len(a)
# Out:
# 4

# %%
for i in a:
  print(i, end = ' ')
# Out:
# 1 23 5 8

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a = np.array([1,23,5,8])
a.dtype
# Out:
# dtype('int64')

# %%
a[0] = 10.6
a
# Out:
# array([10, 23,  5,  8])

# %%
int('12')
# Out:
# 12

# %%
a[2] = 12.6   # dar tabdil float be int , mamoolan be samte paeen gerd mishavad.
a
# Out:
# array([10, 23, 12,  8])

# %%
b = np.array([12.3,10,20,30])
b
# Out:
# array([12.3, 10. , 20. , 30. ])

# %%
b = np.array([12,10.1,20.3,30.8])  # agar araye tarkibi az int , float bashad, ham ro tabdil be float mikonad.
b
# Out:
# array([12. , 10.1, 20.3, 30.8])

# %%
b= np.array([12.3,10,20,30], dtype = str)
b
# Out:
# array(['12.3', '10', '20', '30'], dtype='<U4')

# %%
b= np.array([12.3,10,20,30], dtype = str)

# %%
c = b.astype(float)  # baraye tabdile araye be float
c
# Out:
# array([12.3, 10. , 20. , 30. ])

# %%
print(b.size )  # kole tedade elementhaye yek matrix
print(b)
# Out:
# 4
# [12.3 10.  20.  30. ]

# %%
b.shape # abaade yek matix be soorate tople
# Out:
# (4,)

# %%
b.ndim  # tedade abaade
# Out:
# 1

# %%
c = np.array([[1,4,8,9,5],[5,3,9,2,6]])
c
# Out:
# array([[1, 4, 8, 9, 5],
#        [5, 3, 9, 2, 6]])

# %%
c.shape
# Out:
# (2, 4)

# %%
c.ndim
# Out:
# 2

# %%
c.astype(float)
# Out:
# array([[1., 4., 8., 9.],
#        [5., 3., 9., 2.]])

# %%
c
# Out:
# array([[1, 4, 8, 9],
#        [5, 3, 9, 2]])

# %%
c.size
# Out:
# 8

# %%
c[0]
# Out:
# array([1, 4, 8, 9])

# %%
len(c)
# Out:
# 2

# %%
c[1,2]  # be 2 shekl mitavan be anasore yek matrix dastresi dasht.
# Out:
# 9

# %%
c[1][2]
# Out:
# 9

# %%
c[:,2]
# Out:
# array([8, 9])

# %%
q = c[:,1:4:2]
q
# Out:
# array([[4, 9],
#        [3, 2]])

# %%
q[0,0] = 1000
print(q)
# Out:
# [[1000    9]
#  [   3    2]]

# %%
c
# Out:
# array([[   1, 1000,    8,    9,    5],
#        [   5,    3,    9,    2,    6]])
